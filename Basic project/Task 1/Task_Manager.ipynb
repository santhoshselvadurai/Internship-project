# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
import random
#inititalize an Empty dataframe for tasks
tasks = pd.DataFrame(columns = ['Description','Priority'])
tasks
# Out:
# Empty DataFrame
# Columns: [Description, Priority]
# Index: []

# %%
#functions to save dataframe as a csv file
def save_file():
    tasks.to_csv("tasks.csv",index=False)

# %%
vectorizer = CountVectorizer()
clf = MultinomialNB()
model = make_pipeline(vectorizer, clf)
model.fit(tasks['description'], tasks['priority'])

# %%
def add_task(description, priority):
    global tasks  # Declare tasks as a global variable
    new_task = pd.DataFrame({'Description': [description], 'Priority': [priority]})
    tasks = pd.concat([tasks, new_task], ignore_index=True)
    save_file()

# %%
def remove_task(desc):
    global tasks
    tasks = tasks[tasks["Description"]!=desc]
    save_file()

# %%
def list_task():
    if tasks.empty:
        print("There are no Tasks available")
    else:
        print(tasks)

# %%
def recommend_task():
    if not tasks.empty:
        # Filter tasks by high priority
        high_priority_tasks = tasks[tasks['Priority'] == 'High']
        
        if not high_priority_tasks.empty:
            # Choose a random high-priority task
            random_task = random.choice(high_priority_tasks['Description'].tolist())
            print(f"Recommended task: {random_task} - Priority: High")
        else:
            print("No high-priority tasks available for recommendation.")
    else:
        print("No tasks available for recommendations.")

# %%
while True:
    print("\nTask Management App")
    print("1. Add Task")
    print("2. Remove Task")
    print("3. List Tasks")
    print("4. Recommend Task")
    print("5. Exit")

    choice = input("Select an option: ")

    if choice == "1":
        description = input("Enter task description: ")
        priority = input("Enter task priority (Low/Medium/High): ").capitalize()
        add_task(description, priority)
        print("Task added successfully.")

    elif choice == "2":
        description = input("Enter task description to remove: ")
        remove_task(description)
        print("Task removed successfully.")

    elif choice == "3":
        list_task()

    elif choice == "4":
        recommend_task()

    elif choice == "5":
        print("Goodbye!")
        break

    else:
        print("Invalid option. Please select a valid option.")
# Out:
# Task Management App
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Recommend Task
# 5. Exit
# Select an option: 1
# Enter task description: Buy Grocery
# Enter task priority (Low/Medium/High): High
# Task added successfully.
#
# Task Management App
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Recommend Task
# 5. Exit
# Select an option: 1
# Enter task description: Complete a project report
# Enter task priority (Low/Medium/High): Medium
# Task added successfully.
#
# Task Management App
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Recommend Task
# 5. Exit
# Select an option: 1
# Enter task description: Schedule a meeting with team
# Enter task priority (Low/Medium/High): low
# Task added successfully.
#
# Task Management App
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Recommend Task
# 5. Exit
# Select an option: 1
# Enter task description: prepare a presentation for meeting
# Enter task priority (Low/Medium/High): low
# Task added successfully.
#
# ...

# %%
tasks
# Out:
#                           Description Priority
# 0                         Buy Grocery     High
# 1           Complete a project report   Medium
# 2        Schedule a meeting with team      Low
# 3  prepare a presentation for meeting      Low
# 4                       Pay the bills     High
# 5             Relax and entertainment      Low

# %%
vectorizer = CountVectorizer()
clf = MultinomialNB()
model = make_pipeline(vectorizer, clf)
model.fit(tasks['Description'], tasks['Priority'])
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
model.predict(tasks['Description'])
# Out:
# array(['High', 'Medium', 'Low', 'Low', 'High', 'Low'], dtype='<U6')

# %%
# Assuming 'new_task' is the new task you want to classify
new_task = ['visiting a Friends Home']

# Predict using the trained model directly on raw text data
predicted_category = model.predict(new_task)
print("Predicted Category for new task:", predicted_category[0])
# Out:
# Predicted Category for new task: Low
